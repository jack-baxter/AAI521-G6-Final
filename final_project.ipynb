# %%
#AAI-521 Final Project: Title
#Group 6
#Fall 2025, Dr. Albuyeh
#Jamshed Nabizada, Jack Baxter, Naima Botros

# %% [markdown]
# Part 1 - Data Preprocessing

# %%
#data preproc packages import

# %%
#data preproc cell 1

# %%
#data preproc cell 2

# %%
#data preproc cell 3....

# %% [markdown]
# Part 2 - Model Selection and Training

# %%
#model packages import

# %%
#model cell 1

# %%
#model cell 2

# %%
#model cell 3...

# %% [markdown]
# Part 3 - Evaluation, Analysis, Visualization

# %%
#eval packages import

# %%
#eval cell 1

# %%
#eval cell 2

# %%
#eval cell 3...

# %% [markdown]
# Findings & Final Thoughts

# %% [markdown]
# - quick write up in script
